# %%
# print("welcome to portal\n")
print("check your eligibility\n")
name=input("Enter Your Name")
age=float(input("enter your age:"))##i used float so it can accept both int and float
if(age>18):
    print(f"congratulation {name} ")
    print("you are elgible: ")
elif(age>=17):
    
    print(f"soon you will be eligible in approx{months} months : ")
elif(age==0):
    print(f"hi {name} ")
    print("you entered incorrect age")
else:
    print(f"sorry {name} ")
    print("you are not eligible right now:")
print("\n thank you for using the portal")
# Out:
# check your eligibility
# Enter Your Name 11
# enter your age: 17.11
# soon you will be eligible in approx10 months :
#
#  thank you for using the portal
